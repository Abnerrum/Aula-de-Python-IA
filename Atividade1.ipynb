# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
nome="Eu tô aprendo python"
print(nome)
# Out:
# Eu tô aprendo python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
nome="Meu nome é Maria"
nome1="Eu moro em Recife"


print(nome, '\n', nome1)
# Out:
# Meu nome é Maria
#  Eu moro em Recife

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:

# %%
nome="Meu nome é Ana é tenho"
idade= 18

print(nome,",", idade, "anos")
# Out:
# Meu nome é Ana é tenho , 18 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
nome="Eu moro em Salvador"
pais= "BA,"
localizacao="Brasil"

print(nome,"-", pais, "Páis Tropical")
# Out:
# Eu moro em Salvador - BA, Páis Tropical
